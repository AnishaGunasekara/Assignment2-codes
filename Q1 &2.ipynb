# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
im_og= cv.imread('/content/drive/MyDrive/Image_Processing/cf.jpg')
im_og= cv.cvtColor(im_og, cv.COLOR_BGR2GRAY)

im_2 = cv.Canny(im_og, 550, 690)


plt.subplot(1, 2, 1)
plt.imshow(im_og, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(im_2, cmap='gray')
plt.title('Edges Detected')

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

from google.colab import drive
drive.mount('/content/drive')

im_og= cv.imread('/content/drive/MyDrive/Image_Processing/cf.jpg')
im_og= cv.cvtColor(im_og, cv.COLOR_BGR2GRAY)

im_1 = cv.Canny(im_og, 550, 690)
im_2 = np.argwhere(im_1 > 0)
indices = np.where( im_2 != [ 0 ] )
x= indices [1]
y= indices [0]

x = x.reshape(-1,1)
y = y.reshape(-1,1)

model = LinearRegression()
model.fit(x, y)

im_3 = model.coef_[0]

print("Estimated slope of the crop field", im_3)

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Estimated slope of the crop field [-0.44535519]

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

from google.colab import drive
drive.mount('/content/drive')

im_og= cv.imread('/content/drive/MyDrive/Image_Processing/cf.jpg')
im_og= cv.cvtColor(im_og, cv.COLOR_BGR2GRAY)

im_1 = cv.Canny(im_og, 550, 690)
im_2 = np.argwhere(im_1 > 0)
indices = np.where( im_2 != [ 0 ] )
x= indices [1]
y= indices [0]

x = x.reshape(-1,1)
y = y.reshape(-1,1)

model = LinearRegression()
model.fit(x, y)

im_3 = model.coef_[0]

plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', s=5)
plt.title('Scatterplot of Edge Coordinates')
plt.xlabel('X coordinates')
plt.ylabel('Y coordinates')
plt.grid(True)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
